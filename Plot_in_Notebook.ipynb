# %%
import matplotlib
# %matplotlib inline
import PlotWindData

# %%
import PlotImbalanceData

# %%
import PlotSolarData

# %%
import ServiceImbalance as file
elia_data = file.ImbalanceService()
file.ImbalanceDataPandas(elia_data).head(10)
# Out:
#                          NRV       SI  R2UP   R2DOWN  BIDUP  BIDDOWN  R3FLEX  \
# 2019-07-02 18:15:00  -46.982   55.976   0.0  -41.615    0.0      0.0     0.0
# 2019-07-02 18:16:00  -68.284  127.825   0.0  -54.951    0.0      0.0     0.0
# 2019-07-02 18:17:00  -85.778  114.371   0.0  -74.728    0.0      0.0     0.0
# 2019-07-02 18:18:00 -110.710  133.571   0.0  -94.110    0.0      0.0     0.0
# 2019-07-02 18:19:00 -151.342  210.906   0.0 -113.192    0.0      0.0     0.0
# 2019-07-02 18:20:00 -155.864  151.341   0.0 -132.747    0.0      0.0     0.0
# 2019-07-02 18:21:00 -168.885  186.054   0.0 -144.802    0.0      0.0     0.0
# 2019-07-02 18:22:00 -172.533  170.024   0.0 -145.000    0.0      0.0     0.0
# 2019-07-02 18:23:00 -152.905  124.967   0.0 -142.305    0.0      0.0     0.0
# 2019-07-02 18:24:00 -141.494  119.284   0.0 -132.611    0.0      0.0     0.0
#
#                      R3STD  IGCCUP  IGCCDOWN   R3     aFRR  mFRR
# ...

# %%
import PlotLoadData

# %%
import PlotImbalancePriceData
